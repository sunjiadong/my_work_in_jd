# %%
###f01###
# -*- coding: utf-8 -*-
import warnings
import os.path
from code.refactor.common import (get_setting_from_cfg, get_setting_path, filter_df_by_cate_id,get_future_sales_feature,\
                                  dummy_features, model_predict, get_weekly_df,get_future_condition_sales_feature,gen_train_valid_by_date,\
                                  generate_promotion_future, get_hour, save_object, add_pv,get_lowest_n,generate_cv_train_valid_set,\
                                  generate_default_values_by_dic,fill_col_with_default, week2month,trans_band_to_int,get_future_condition_sales_feature_stage2,\
                                  loadSettingsFromYamlFile,createSeasonalityFeatures,createLevel3Features,createSeasonalityDecomposeFeatures,\
                                 calculateNationalRolling,calculateRolling,calculateLagging,createDateFeatures,splitTimeWindow,calculateSimilarRolling,calculateStockFeatures,\
                                 process_rdc,clean_data,add_cols,get_dd_price,agg_dd_price,get_bundle_feat,agg_bd_price,process_feature,\
                                 agg_feature,prep_data,calc_weighted_price,agg_feature_day,get_column_by_type,object2Float,object2Int)
from code.refactor.fdc_flow import  filter_non_price_fill_it
import pandas as pd
import xgboost as xgb
import numpy as np
import datetime
warnings.filterwarnings("ignore", category=DeprecationWarning)

#p1_path = 'tmp/0411_2018_brand/p1_0411.csv' 

path = 'tmp/data/to_xiaolu'
suffix = '.da'
item = 'p1'
for_what = ['train', 'predict']
cate_list = [12240,12250,15123]
#cate_list = [2584, 2589, 12029]
scenarioSettingsPath = 'code/refactor/ow_scenario.yaml'
scenario = loadSettingsFromYamlFile(scenarioSettingsPath)
area_rdc_map = pd.read_csv('/home/ubuntu/yulong/promotion_offline/tmp/ow_deploy_single/area_rdc_mapping.csv')
import ow_f01
# Out:
# /home/ubuntu/lijingjie/ljj/local/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
cate = 12243
train_pred_gate = 'train'
os.path.join(path, str(cate)+'/'+str(cate)+'_'+item+suffix)
timerange = ['2017-09-26','2017-12-20','2018-03-19']

# %%
for start_date in timerange:
    print os.path.join(path, str(cate)+'/'+train_pred_gate+'_'+item+'_'+str(cate)+'_'+str(start_date)+'.csv')
# Out:
# tmp/data/to_xiaolu/12243/train_p1_12243_2017-09-26.csv
# tmp/data/to_xiaolu/12243/train_p1_12243_2017-12-20.csv
# tmp/data/to_xiaolu/12243/train_p1_12243_2018-03-19.csv

# %%
for start_date in timerange:
    for fw in for_what:
        for cate in cate_list:
            print "output and save: %s_p1_%s"%(str(cate),fw)
            p1_path = os.path.join(path, str(cate)+'/'+str(cate)+'_'+item+suffix)

            p1_used_header=['productkey', 'promotionkey', 'startdatetime', 'enddatetime', 'jdprice', 'syntheticgrossprice', 'promotiondesc', 'promotiondesc_flag', 'promotiontype', 'promotionsubtype',
                        'areatypearray', 'tokenflag', 'directdiscount_discount', 'directdiscount_availabilitynumber', 'bundle_subtype1_threshold', 'bundle_subtype1_giveaway',
                        'bundle_subtype4_threshold1', 'bundle_subtype4_giveaway1', 'bundle_subtype4_threshold2', 'bundle_subtype4_giveaway2', 'bundle_subtype4_threshold3',
                        'bundle_subtype4_giveaway3', 'bundle_subtype2_threshold', 'bundle_subtype2_giveaway', 'bundle_subtype2_maximumgiveaway', 'bundle_subtype15_thresholdnumber1',
                        'bundle_subtype15_giveawayrate1', 'bundle_subtype15_thresholdnumber2', 'bundle_subtype15_giveawayrate2', 'bundle_subtype15_thresholdnumber3',
                        'bundle_subtype15_giveawayrate3', 'bundle_subtype6_thresholdnumber', 'bundle_subtype6_freenumber', 'suit_maxvaluepool', 'suit_minvaluepool', 'suit_avgvaluepool',
                        'suit_discount', 'directdiscount_saleprice', 'bundle_subtype1_percent', 'bundle_subtype4_percent', 'bundle_subtype2_percent', 'bundle_subtype15_percent',
                        'bundle_subtype6_percent', 'suit_percent', 'allpercentdiscount', 'mainproductkey', 'hierarchylevel3key', 'createdate', 'statuscode', 'dt']
            period_promo_raw = pd.read_csv(p1_path,sep='\t',header=None)
            period_promo_raw.columns=p1_used_header

            period_promo_raw_clean = period_promo_raw
            train_pred_gate = fw   # 'train'
            pred_date = pd.to_datetime(start_date)
            scenario['lookforwardPeriodDays'] = 91
            f01_output = ow_f01.generate_f01_promo(area_rdc_map, period_promo_raw_clean,scenario, train_pred_gate, ForecastStartDate=pred_date)
            f01_output.to_csv(os.path.join(path, str(cate)+'/'+train_pred_gate+'_'+item+'_'+str(cate)+'_'+str(start_date)+'.csv'),index=False)
# Out:
# output and save: 12240_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 36487)
# ('| - Filtered tokens: ', 36381)
# ('| - Filtered descriptions: ', 36258)
# ('| - Filtered flash sale available units', 35461)
# ('| - Filtered non-national promo: ', 35458)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (348223, 23)
# output and save: 12250_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 29923)
# ('| - Filtered tokens: ', 29486)
# ('| - Filtered descriptions: ', 28802)
# ('| - Filtered flash sale available units', 28400)
# ('| - Filtered non-national promo: ', 27158)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (130947, 23)
# output and save: 15123_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 31732)
# ('| - Filtered tokens: ', 31724)
# ('| - Filtered descriptions: ', 31642)
# ('| - Filtered flash sale available units', 31223)
# ('| - Filtered non-national promo: ', 29998)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (348026, 23)
# output and save: 12240_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 10003)
# ('| - Filtered tokens: ', 9886)
# ('| - Filtered descriptions: ', 9817)
# ('| - Filtered flash sale available units', 9431)
# ('| - Filtered non-national promo: ', 9431)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (166533, 23)
# output and save: 12250_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 9176)
# ('| - Filtered tokens: ', 9070)
# ('| - Filtered descriptions: ', 8579)
# ('| - Filtered flash sale available units', 8558)
# ('| - Filtered non-national promo: ', 8488)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (49725, 23)
# output and save: 15123_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 14898)
# ('| - Filtered tokens: ', 14470)
# ('| - Filtered descriptions: ', 14181)
# ('| - Filtered flash sale available units', 14020)
# ('| - Filtered non-national promo: ', 13855)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (232145, 23)
# output and save: 12240_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 36461)
# ('| - Filtered tokens: ', 36255)
# ('| - Filtered descriptions: ', 36123)
# ('| - Filtered flash sale available units', 34953)
# ('| - Filtered non-national promo: ', 34952)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (277138, 23)
# output and save: 12250_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 36349)
# ('| - Filtered tokens: ', 35847)
# ('| - Filtered descriptions: ', 34793)
# ('| - Filtered flash sale available units', 34376)
# ('| - Filtered non-national promo: ', 33079)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (130948, 23)
# output and save: 15123_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 42425)
# ('| - Filtered tokens: ', 41993)
# ('| - Filtered descriptions: ', 41635)
# ('| - Filtered flash sale available units', 41055)
# ('| - Filtered non-national promo: ', 39995)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (344437, 23)
# output and save: 12240_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 13551)
# ('| - Filtered tokens: ', 13505)
# ('| - Filtered descriptions: ', 13353)
# ('| - Filtered flash sale available units', 12938)
# ('| - Filtered non-national promo: ', 12938)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (158600, 23)
# output and save: 12250_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 15207)
# ('| - Filtered tokens: ', 15207)
# ('| - Filtered descriptions: ', 14326)
# ('| - Filtered flash sale available units', 14314)
# ('| - Filtered non-national promo: ', 13956)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (43582, 23)
# output and save: 15123_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 31051)
# ('| - Filtered tokens: ', 30977)
# ('| - Filtered descriptions: ', 30967)
# ('| - Filtered flash sale available units', 30024)
# ('| - Filtered non-national promo: ', 28023)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (213719, 23)
# output and save: 12240_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 35308)
# ('| - Filtered tokens: ', 35096)
# ('| - Filtered descriptions: ', 34820)
# ('| - Filtered flash sale available units', 33475)
# ('| - Filtered non-national promo: ', 33474)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (274197, 23)
# output and save: 12250_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 47465)
# ('| - Filtered tokens: ', 46985)
# ('| - Filtered descriptions: ', 45158)
# ('| - Filtered flash sale available units', 44729)
# ('| - Filtered non-national promo: ', 43113)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (130867, 23)
# output and save: 15123_p1_train
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 67813)
# ('| - Filtered tokens: ', 67344)
# ('| - Filtered descriptions: ', 66982)
# ('| - Filtered flash sale available units', 65463)
# ('| - Filtered non-national promo: ', 62469)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (359250, 23)
# output and save: 12240_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 10921)
# ('| - Filtered tokens: ', 10920)
# ('| - Filtered descriptions: ', 10917)
# ('| - Filtered flash sale available units', 10867)
# ('| - Filtered non-national promo: ', 10867)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (135141, 23)
# output and save: 12250_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 6985)
# ('| - Filtered tokens: ', 6985)
# ('| - Filtered descriptions: ', 6578)
# ('| - Filtered flash sale available units', 6571)
# ('| - Filtered non-national promo: ', 6570)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (43096, 23)
# output and save: 15123_p1_predict
# convert to Float columns:
# allpercentdiscount
# convert to Float columns:
# bundle_subtype15_giveawayrate1
# convert to Float columns:
# bundle_subtype15_giveawayrate2
# convert to Float columns:
# bundle_subtype15_giveawayrate3
# convert to Float columns:
# bundle_subtype15_percent
# convert to Float columns:
# bundle_subtype15_thresholdnumber1
# convert to Float columns:
# bundle_subtype15_thresholdnumber2
# convert to Float columns:
# bundle_subtype15_thresholdnumber3
# convert to Float columns:
# bundle_subtype1_giveaway
# convert to Float columns:
# bundle_subtype1_percent
# convert to Float columns:
# bundle_subtype1_threshold
# convert to Float columns:
# bundle_subtype2_giveaway
# convert to Float columns:
# bundle_subtype2_maximumgiveaway
# convert to Float columns:
# bundle_subtype2_percent
# convert to Float columns:
# bundle_subtype2_threshold
# convert to Float columns:
# bundle_subtype4_giveaway1
# convert to Float columns:
# bundle_subtype4_giveaway2
# convert to Float columns:
# bundle_subtype4_giveaway3
# convert to Float columns:
# bundle_subtype4_percent
# convert to Float columns:
# bundle_subtype4_threshold1
# convert to Float columns:
# bundle_subtype4_threshold2
# convert to Float columns:
# bundle_subtype4_threshold3
# convert to Float columns:
# bundle_subtype6_freenumber
# convert to Float columns:
# bundle_subtype6_percent
# convert to Float columns:
# bundle_subtype6_thresholdnumber
# convert to Float columns:
# directdiscount_availabilitynumber
# convert to Float columns:
# directdiscount_discount
# convert to Float columns:
# directdiscount_saleprice
# convert to Float columns:
# hierarchylevel3key
# convert to Float columns:
# jdprice
# convert to Float columns:
# mainproductkey
# convert to Float columns:
# productkey
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# promotiontype
# convert to Float columns:
# statuscode
# convert to Float columns:
# suit_avgvaluepool
# convert to Float columns:
# suit_discount
# convert to Float columns:
# suit_maxvaluepool
# convert to Float columns:
# suit_minvaluepool
# convert to Float columns:
# suit_percent
# convert to Float columns:
# syntheticgrossprice
# ('| - Before filter: ', 29490)
# ('| - Filtered tokens: ', 29490)
# ('| - Filtered descriptions: ', 29314)
# ('| - Filtered flash sale available units', 29088)
# ('| - Filtered non-national promo: ', 28957)
# | | - Add additional columns
# | | - Calculate dd price per promotion
# | | - Calculate dd price per period
# | | - Generate bundle features
# | | - Calculate bundle price per period
# | - Reformat date
# | | - process features
# | | - aggregate features per period
# | | - prep data for Step 3
# | | - fix indicators on days with end time 00:00 or start time 23:59
# | | - calculate weighted price per day
# | | - aggregate features per day
# f01 shape
# (113737, 23)

# %%
import warnings
import os.path
from code.refactor.common import (get_setting_from_cfg, get_setting_path, filter_df_by_cate_id,get_future_sales_feature,\
                                  dummy_features, model_predict, get_weekly_df,get_future_condition_sales_feature,gen_train_valid_by_date,\
                                  generate_promotion_future, get_hour, save_object, add_pv,get_lowest_n,generate_cv_train_valid_set,\
                                  generate_default_values_by_dic,fill_col_with_default, week2month,trans_band_to_int,get_future_condition_sales_feature_stage2,\
                                  loadSettingsFromYamlFile,createSeasonalityFeatures,createLevel3Features,createSeasonalityDecomposeFeatures,\
                                 calculateNationalRolling,calculateRolling,calculateLagging,createDateFeatures,splitTimeWindow,calculateSimilarRolling,calculateStockFeatures,\
                                 process_rdc,clean_data,add_cols,get_dd_price,agg_dd_price,get_bundle_feat,agg_bd_price,process_feature,\
                                 agg_feature,prep_data,calc_weighted_price,agg_feature_day,get_column_by_type,object2Float,object2Int)
from code.refactor.fdc_flow import  filter_non_price_fill_it
import pandas as pd
import xgboost as xgb
import numpy as np
import datetime
warnings.filterwarnings("ignore", category=DeprecationWarning)

# %%
path = 'tmp/data/to_xiaolu'
result_path = 'tmp/data/to_xiaolu'
cate_list = [12240,12250,15123]
#cate_list = [7052, 7054, 870]
scenarioSettingsPath = 'code/refactor/ow_scenario.yaml'
scenario = loadSettingsFromYamlFile(scenarioSettingsPath)
'''online analysis'''
#scenario['use_cart_feature'] = False
#scenario['use_promo_features'] = False
holidays_df=pd.read_csv('/home/ubuntu/yulong/promotion_offline/tmp/ow_deploy_single/holidays.csv')
area_rdc_map = pd.read_csv('/home/ubuntu/yulong/promotion_offline/tmp/ow_deploy_single/area_rdc_mapping.csv')
import ow_train
reload(ow_train)
# Out:
# <module 'ow_train' from 'ow_train.pyc'>

# %%
timerange
# Out:
# ['2017-09-26', '2017-12-20', '2018-03-19']

# %%
os.path.join(path, str(cate)+'/'+'train'+'_p1_'+str(cate)+'_'+str(start_date)+'.csv')
# Out:
# 'tmp/data/to_xiaolu/15123/train_p1_15123_2018-03-19.csv'

# %%
for start_date in timerange:
    for cate in cate_list:
        pred_date = pd.to_datetime(start_date)
        scenario['lookforwardPeriodDays'] = 91

        pro_canlender_path = os.path.join(path, str(cate)+'/'+str(cate)+'_'+'p2.da')
        promoCalendarDf = pd.read_csv(pro_canlender_path,sep='\t',header=None)
        promoCalendarDf.columns=['ProductKey', 'Date', 'HierarchyLevel3Key', 'PromotionCount', 'bundlecount', 'MaxDiscount', 'MinDiscount', 'AvgDiscount', 'MaxSyntheticDiscountA',
                 'MinSyntheticDiscountA', 'AvgSyntheticDiscountA', 'MaxBundleDiscount', 'MinBundleDiscount', 'AvgBundleDiscount', 'MaxDirectDiscount', 'MinDirectDiscount',
                 'AvgDirectDiscount', 'MaxFreegiftDiscount', 'MinFreegiftDiscount', 'AvgFreegiftDiscount', 'SyntheticGrossPrice', 'promotionkey', 'promotiontype',
                 'promotionsubtype', 'syntheticgrossprice_vb', 'jdprice', 'syntheticdiscounta_vb', 'durationinhours', 'daynumberinpromotion', 'bundleflag', 'directdiscountflag',
                 'freegiftflag', 'suitflag', 'numberproducts', 'numberhierarchylevel1', 'numberhierarchylevel2', 'numberhierarchylevel3', 'strongmark', 'stockprice', 'dt']

        p1_out_path = os.path.join(path, str(cate)+'/'+'train'+'_p1_'+str(cate)+'_'+str(start_date)+'.csv')
        period_promo_raw = pd.read_csv(p1_out_path,parse_dates=['Date'])

        #sea_path = os.path.join(path, str(cate)+'_season.csv')
        seasonality_df = pd.read_csv('tmp/data/870_season.csv', parse_dates=['Date'])

        file_path = os.path.join(path, str(cate)+'/'+str(cate)+'_'+'ts.da')
        ts_df = pd.read_csv(file_path,header=None,sep='\t')
        model,feature=ow_train.train(area_rdc_map,period_promo_raw,promoCalendarDf,ts_df,scenario,holidays_df,seasonality_df,process_f01_flag=False,mode='dev',ForecastStartDate=pred_date)
        #feature.to_csv(os.path.join(result_path, str(cate)+'_train_feature_with_season_180201_0515.csv'),index=False)
        save_object(model, os.path.join(result_path, str(cate)+'/'+str(cate)+'_train_model_'+str(start_date)+'.pkl'))
# Out:
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# ow_train.py:51: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ts_df_pred.replace('null', np.nan, inplace=True)
# ow_train.py:52: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ts_df_pred.replace(-999, np.nan, inplace=True)
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.547313 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 3.711384 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.269109 seconds
#
# | - process group: 2, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.733200 seconds
#
# | - process group: 3, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.077782 seconds
#
# | - process group: 4, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.362135 seconds
#
# | - process group: 5, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.147182 seconds
#
# | - process group: 6, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.770780 seconds
#
# | - process group: 7, code: 100240.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.643873 seconds
#
# | - process group: 8, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.674200 seconds
#
# | - process group: 9, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.106640 seconds
#
# | - process group: 10, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.997417 seconds
#
# | - process group: 11, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.872477 seconds
#
# | - Added rolling features in 12.518546 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.556220 seconds
#
# featuresDf shape
# (59167, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.695530 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.657337 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.589924 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.006082 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.981622 seconds
#
# | - process group: 4, code: 11050.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.765689 seconds
#
# | - process group: 5, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.919615 seconds
#
# | - process group: 6, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.902287 seconds
#
# | - process group: 7, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.876686 seconds
#
# | - process group: 8, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.864570 seconds
#
# | - process group: 9, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.906631 seconds
#
# | - process group: 10, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.659215 seconds
#
# | - process group: 11, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.902982 seconds
#
# | - Added rolling features in 10.872577 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.406292 seconds
#
# featuresDf shape
# (31514, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.813837 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.828348 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.653139 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.088323 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.929061 seconds
#
# | - process group: 4, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.977995 seconds
#
# | - process group: 5, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.635409 seconds
#
# | - process group: 6, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.872418 seconds
#
# | - process group: 7, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.611065 seconds
#
# | - process group: 8, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.784800 seconds
#
# | - process group: 9, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.672696 seconds
#
# | - process group: 10, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.676373 seconds
#
# | - Added rolling features in 9.256201 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.392159 seconds
#
# featuresDf shape
# (28564, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.329072 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 3.692598 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.252793 seconds
#
# | - process group: 2, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.710484 seconds
#
# | - process group: 3, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.927951 seconds
#
# | - process group: 4, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.075959 seconds
#
# | - process group: 5, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.896725 seconds
#
# | - process group: 6, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.639361 seconds
#
# | - process group: 7, code: 100240.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.581825 seconds
#
# | - process group: 8, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.618121 seconds
#
# | - process group: 9, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.090597 seconds
#
# | - process group: 10, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.729968 seconds
#
# | - process group: 11, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.801771 seconds
#
# | - Added rolling features in 11.103167 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.561190 seconds
#
# featuresDf shape
# (65588, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.766552 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.624151 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.614258 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.907872 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.847417 seconds
#
# | - process group: 4, code: 11050.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.606660 seconds
#
# | - process group: 5, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.659954 seconds
#
# | - process group: 6, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.725262 seconds
#
# | - process group: 7, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.729253 seconds
#
# | - process group: 8, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.800450 seconds
#
# | - process group: 9, code: 100151.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.588131 seconds
#
# | - process group: 10, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.816319 seconds
#
# | - process group: 11, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.621286 seconds
#
# | - process group: 12, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.855019 seconds
#
# | - Added rolling features in 10.208672 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.422076 seconds
#
# featuresDf shape
# (36779, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.891925 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.971266 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.746795 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.833054 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.897684 seconds
#
# | - process group: 4, code: 11050.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.583478 seconds
#
# | - process group: 5, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.948677 seconds
#
# | - process group: 6, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.718730 seconds
#
# | - process group: 7, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.904250 seconds
#
# | - process group: 8, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.694797 seconds
#
# | - process group: 9, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.585101 seconds
#
# | - process group: 10, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.892750 seconds
#
# | - Added rolling features in 9.144280 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.416851 seconds
#
# featuresDf shape
# (36394, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.101084 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# ...
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.520287 seconds
#
# featuresDf shape
# (56571, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.720342 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.714441 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.685166 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.939761 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.082845 seconds
#
# | - process group: 4, code: 11050.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.589601 seconds
#
# | - process group: 5, code: 100011.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.658727 seconds
#
# | - process group: 6, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.751852 seconds
#
# | - process group: 7, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.754872 seconds
#
# | - process group: 8, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.795493 seconds
#
# | - process group: 9, code: 100151.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.578199 seconds
#
# | - process group: 10, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.940327 seconds
#
# | - process group: 11, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.632248 seconds
#
# | - process group: 12, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.829611 seconds
#
# | - Added rolling features in 10.695304 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.468885 seconds
#
# featuresDf shape
# (41813, 141)
# rdc
# 3
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# use cart feature?
# False
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | Calculating national rolling features...
# ('| - Rolling value:', 'xxxHashColumn')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.413340 seconds
#
# | Calculating  rolling features...
# ('| - Rolling value:', 'OrderNonOutlierVolume')
# | - Rolling 360 mean...
# | - Rolling 180 mean...
# | - Rolling 90 mean...
# | - Rolling 28 mean...
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 360 mean...
# | - Rolling decay 180 mean...
# | - Rolling decay 90 mean...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 3.794547 seconds
#
# | Calculating similar rolling features...
# | - group by SyntheticPromotionSubType...
# | - process group: 1, code: 0.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 2.244260 seconds
#
# | - process group: 2, code: 11010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.967561 seconds
#
# | - process group: 3, code: 100040.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.274647 seconds
#
# | - process group: 4, code: 11050.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.573261 seconds
#
# | - process group: 5, code: 10160.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 1.026309 seconds
#
# | - process group: 6, code: 100020.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.809955 seconds
#
# | - process group: 7, code: 100150.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.837224 seconds
#
# | - process group: 8, code: 11060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.758301 seconds
#
# | - process group: 9, code: 10100.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.847880 seconds
#
# | - process group: 10, code: 100060.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.592880 seconds
#
# | - process group: 11, code: 100010.0...
# | Calculating similar rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Rolling 14 mean...
# | - Rolling 7 mean...
# | - Rolling 5 mean...
# | - Rolling 3 mean...
# | - Rolling 2 mean...
# | - Rolling 1 mean...
# | - Rolling 14 median...
# | - Rolling 7 median...
# | - Rolling decay 28 mean...
# | - Rolling decay 14 mean...
# | - Rolling decay 7 mean...
# | - Rolling decay 3 mean...
# | - Added rolling features in 0.849500 seconds
#
# | - Added rolling features in 11.277701 seconds
#
# | Calculating volume rolling features...
# ('| - Rolling value:', 'salesForecast')
# | - Shift 365...
# | - Shift 180...
# | - Shift 90...
# | - Shift 30...
# | - Shift 7...
# | - Added rolling features in 0.501390 seconds
#
# featuresDf shape
# (51582, 141)
# rdc
# 3

# %%
xgb.__version__
# Out:
# '0.7.post4'

# %%
###predict###
# -*- coding: utf-8 -*-
import warnings
import os.path
from code.refactor.common import (get_setting_from_cfg, get_setting_path, filter_df_by_cate_id,get_future_sales_feature,\
                                  dummy_features, model_predict, get_weekly_df,get_future_condition_sales_feature,gen_train_valid_by_date,\
                                  generate_promotion_future, get_hour, save_object, add_pv,get_lowest_n,generate_cv_train_valid_set,\
                                  generate_default_values_by_dic,fill_col_with_default, week2month,trans_band_to_int,get_future_condition_sales_feature_stage2,\
                                  loadSettingsFromYamlFile,createSeasonalityFeatures,createLevel3Features,createSeasonalityDecomposeFeatures,\
                                 calculateNationalRolling_predict,calculateRolling_predict,calculateLagging_predict,createDateFeatures,splitTimeWindow,calculateSimilarRolling_predict,calculateStockFeatures,\
                                 process_rdc,clean_data,add_cols,get_dd_price,agg_dd_price,get_bundle_feat,agg_bd_price,process_feature,\
                                 agg_feature,prep_data,calc_weighted_price,agg_feature_day,get_column_by_type,object2Float,object2Int)
from code.refactor.fdc_flow import  filter_non_price_fill_it
import pandas as pd
import xgboost as xgb
import numpy as np
import datetime
import pickle

scenarioSettingsPath = 'code/refactor/ow_scenario.yaml'
scenario = loadSettingsFromYamlFile(scenarioSettingsPath)

# %%
path = 'tmp/data/to_xiaolu'
result_path = 'tmp/data/to_xiaolu'
cate_list = [12240,12250,15123]
#cate_list = [7052, 7054, 870]

holidays_df=pd.read_csv('/home/ubuntu/yulong/promotion_offline/tmp/ow_deploy_single/holidays.csv')
area_rdc_map = pd.read_csv('/home/ubuntu/yulong/promotion_offline/tmp/ow_deploy_single/area_rdc_mapping.csv')
import ow_predict

# %%
for start_date in timerange:
    for cate in cate_list:
        pred_date = pd.to_datetime(start_date)
        scenario['lookforwardPeriodDays'] = 91

        pro_canlender_path = os.path.join(path, str(cate)+'/'+str(cate)+'_'+'p2.da')
        promoCalendarDf = pd.read_csv(pro_canlender_path,sep='\t',header=None)
        promoCalendarDf.columns=['ProductKey', 'Date', 'HierarchyLevel3Key', 'PromotionCount', 'bundlecount', 'MaxDiscount', 'MinDiscount', 'AvgDiscount', 'MaxSyntheticDiscountA',
               'MinSyntheticDiscountA', 'AvgSyntheticDiscountA', 'MaxBundleDiscount', 'MinBundleDiscount', 'AvgBundleDiscount', 'MaxDirectDiscount', 'MinDirectDiscount',
               'AvgDirectDiscount', 'MaxFreegiftDiscount', 'MinFreegiftDiscount', 'AvgFreegiftDiscount', 'SyntheticGrossPrice', 'promotionkey', 'promotiontype',
               'promotionsubtype', 'syntheticgrossprice_vb', 'jdprice', 'syntheticdiscounta_vb', 'durationinhours', 'daynumberinpromotion', 'bundleflag', 'directdiscountflag',
               'freegiftflag', 'suitflag', 'numberproducts', 'numberhierarchylevel1', 'numberhierarchylevel2', 'numberhierarchylevel3', 'strongmark', 'stockprice', 'dt']

        p1_out_path = os.path.join(path, str(cate)+'/'+'predict'+'_p1_'+str(cate)+'_'+str(start_date)+'.csv')
        period_promo_raw = pd.read_csv(p1_out_path,parse_dates=['Date'])

        file_path = os.path.join(path, str(cate)+'/'+str(cate)+'_'+'ts.da')
        ts_df = pd.read_csv(file_path,header=None,sep='\t')

        model_path = os.path.join(result_path, str(cate)+'/'+str(cate)+'_train_model_'+str(start_date)+'.pkl')
        with open(model_path,'r') as input:
            model = pickle.load(input)

        seasonality_df = pd.read_csv('tmp/data/870_season.csv', parse_dates=['Date'])


        result,df_fut=ow_predict.predict(area_rdc_map,period_promo_raw,promoCalendarDf,ts_df,scenario,holidays_df,model,seasonality_df,process_f01_flag=False,mode='dev',ForecastStartDate=pred_date)
        result.to_csv(os.path.join(result_path, str(cate)+'/'+'result_'+str(cate)+'_'+str(start_date)+'.csv'),index=False)
# Out:
# ow_predict.py:46: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ts_df.replace('null', np.nan, inplace=True)
# ow_predict.py:47: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ts_df.replace(-999, np.nan, inplace=True)
# ow_predict.py:48: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   ts_df.replace('None', np.nan, inplace=True)
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# code/refactor/common.py:1363: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   + df_past[similarLevels[2]]
# code/refactor/common.py:1364: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   df_past['SyntheticPromotionSubType'] = df_past['SyntheticPromotionSubType'].fillna(0.0)
# | - group by SyntheticPromotionSubType...
# ow_predict.py:454: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   pred_df['ypred'] =ypred
# ow_predict.py:455: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   pred_df['RDCKey'] = rdc
# /home/ubuntu/lijingjie/ljj/local/lib/python2.7/site-packages/pandas/core/indexing.py:537: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self.obj[item] = s
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# convert to Float columns:
# stockprice
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...
# convert to Int columns:
# Holiday
# convert to Int columns:
# Ind_1111_pre
# convert to Int columns:
# Ind_1111
# convert to Int columns:
# Ind_1111_post
# convert to Int columns:
# Ind_618_pre
# convert to Int columns:
# Ind_618
# convert to Int columns:
# Ind_618_post
# convert to Int columns:
# Ind_1212
# convert to Float columns:
# MaxSyntheticDiscountA
# convert to Float columns:
# MinSyntheticDiscountA
# convert to Float columns:
# AvgSyntheticDiscountA
# convert to Float columns:
# SyntheticGrossPrice
# convert to Float columns:
# promotionkey
# convert to Float columns:
# promotiontype
# convert to Float columns:
# promotionsubtype
# convert to Float columns:
# syntheticgrossprice_vb
# convert to Float columns:
# jdprice
# convert to Float columns:
# syntheticdiscounta_vb
# convert to Float columns:
# durationinhours
# convert to Float columns:
# daynumberinpromotion
# convert to Float columns:
# bundleflag
# convert to Float columns:
# directdiscountflag
# convert to Float columns:
# freegiftflag
# convert to Float columns:
# suitflag
# | Add date features...
# | - Add month of the year...
# | - Add day of the week...
# | - group by SyntheticPromotionSubType...

# %%
ts_df.RDCKey.unique()
# Out:
# array([3])
